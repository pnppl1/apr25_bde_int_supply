# %%
import pandas as pd

# --- Data File Path ---

data_file_path = "../../1_data_collection/extracting_company_data/general_info.csv"

# --- Load Data ---

df_companies = pd.read_csv(data_file_path)
#print(f"Data successfully loaded from: {data_file_path}")

#df_companies.head(15)
df_companies.describe()
df_companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1040 entries, 0 to 1039
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   company        1040 non-null   object
#  1   website        1040 non-null   object
#  2   rating         1039 non-null   float64
#  3   number_review  1039 non-null   float64
#  4   domain         1040 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 40.8+ KB

# %%
# --- Visualize Top 40 Domain Combinations ---

domain_combination_counts = df_companies['domain'].value_counts()

# Select only the top 40 most frequent domain combinations for visualization.
top_40_combinations = domain_combination_counts.head(40)

# Adjust plot height dynamically based on the number of combinations being plotted.
# We ensure enough vertical space for each bar label to be readable.
plot_height = max(10, len(top_40_combinations) * 0.5) # Minimum 10 inches height
plt.figure(figsize=(12, plot_height)) # Set the figure size (width, height)

# Create a horizontal bar chart.
# x-axis: The counts (numerical values) for each combination.
# y-axis: The unique domain combinations (converted to string for plotting labels).
ax = sns.barplot(x=top_40_combinations.values, y=top_40_combinations.index.astype(str), palette='viridis')

# Add the numerical count labels on each bar.
# This loop iterates through the bars and places the count text next to each.
for index, value in enumerate(top_40_combinations.values):
    ax.text(value + 0.2, # X-position: slightly to the right of the bar's end
            index,       # Y-position: centered on the bar
            str(value),  # The count value itself (as a string)
            va='center', # Vertical alignment: center the text on the bar
            ha='left',   # Horizontal alignment: left-align the text (starts after the bar)
            fontsize=10,
            color='black')
# Out:
# C:\Users\Dom\AppData\Local\Temp\ipykernel_12056\63936943.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=top_40_combinations.values, y=top_40_combinations.index.astype(str), palette='viridis')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import ast # For safely converting string representations of lists

# --- Data Cleaning and Preparation ---

# Ensure df_companies exists from the previous cell.
if 'df_companies' not in locals():
    print("Error: 'df_companies' DataFrame not found. Please run the data loading cell first.")
    sys.exit("Processing terminated: Data not loaded.")

# Convert 'domain' column strings to actual Python lists.
# Handles cases where data might already be in list format.
try:
    if isinstance(df_companies['domain'].iloc[0], str):
        df_companies['domain'] = df_companies['domain'].apply(lambda x: ast.literal_eval(x.strip()))
    else:
        print("Domain column already in list format or unexpected type. Skipping string evaluation.")
except Exception as e:
    print(f"Error parsing 'domain' column: {e}")
    sys.exit("Processing terminated due to domain column error.")

# Explode the 'domain' column to have one category per row.
df_exploded_categories = df_companies.explode('domain')

# Clean category names: remove trailing '...' and whitespace.
df_exploded_categories['domain'] = df_exploded_categories['domain'].str.replace(r'\.\.\.$', '', regex=True).str.strip()

# Calculate frequencies of all unique domain categories.
all_category_counts = df_exploded_categories['domain'].value_counts()

# --- Display All Categories (Table) ---

# Convert counts to a DataFrame for a clear table view.
df_all_categories_table = all_category_counts.reset_index()
df_all_categories_table.columns = ['Domain Category', 'Number of Companies']

print("\n" + "="*50)
print("--- All Domain Categories and their Frequencies ---")
print("="*50)
print(df_all_categories_table.to_string(index=False)) # Print without pandas index
print("="*50 + "\n")

# --- Visualize Top 40 Categories ---

# Select the top 40 most frequent categories for the plot.
top_40_categories = all_category_counts.head(40)

# Adjust plot height dynamically for better readability.
plot_height = max(10, len(top_40_categories) * 0.5)
plt.figure(figsize=(12, plot_height))

# Create a horizontal bar chart.
ax = sns.barplot(x=top_40_categories.values, y=top_40_categories.index, palette='viridis')

# Add count labels on each bar.
for index, value in enumerate(top_40_categories.values):
    ax.text(value + 0.2, index, str(value), va='center', ha='left', fontsize=10, color='black')

# Set plot title and labels.
plt.title('Top 40 Domain Categories (Number of Companies)', fontsize=16)
plt.xlabel('Number of Companies', fontsize=12)
plt.ylabel('Domain Category', fontsize=12)

# Adjust X-axis limit to ensure labels fit.
plt.xlim(right=top_40_categories.values.max() * 1.2)

# Add grid lines for readability.
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Optimize plot layout.
plt.tight_layout()

# Display the plot.
plt.show()
# Out:
# Domain column already in list format or unexpected type. Skipping string evaluation.
#
# ==================================================
# --- All Domain Categories and their Frequencies ---
# ==================================================
#                         Domain Category  Number of Companies
#                           Travel Agency                  721
#                     Flights Search Site                  205
#                           Tour Operator                  165
#                       Travel Aggregator                  132
#                         Vacation Rental                   94
#                   Airline Ticket Agency                   91
#                                   Hotel                   84
#                       Travel & Vacation                   76
#                                 Airline                   58
#                             Tour Agency                   42
#                           Cruise Agency                   32
#                 Cultural Tours Provider                   31
#                         Visa Consultant                   23
#                    Cruise Travel Agency                   22
#             Vacation Home Rental Agency                   22
#                             Parking Lot                   19
#                Visa and Passport Office                   19
#           Holiday Accommodation Service                   18
#                Travel Insurance Company                   17
#                  Transportation Service                   14
#                                 Lodging                   14
#                 Airport Shuttle Service                   13
#                       Car Rental Agency                   13
#                   Car Accessories Store                   12
#              Pet-Friendly Accommodation                   11
#                        Software Company                   11
#                 Sightseeing Tour Agency                   11
#                            Taxi Service                   10
#                    Financial Consultant                   10
#                Holiday Apartment Rental                   10
#                         Passport Office                    9
#                            Ski Holidays                    9
#                   Bus and Coach Company                    8
#                        Insurance Agency                    8
#                         Bus Tour Agency                    8
#                       Limousine Service                    7
#                          Boutique Hotel                    7
#             Association or Organization                    6
#                            Budget Hotel                    6
#             Property Management Company                    6
#                        Timeshare Agency                    6
#             Self-Catering Accommodation                    5
#                             Bus Charter                    5
#                            Luxury Hotel                    5
#                     Cruise Line Company                    5
#                      Online Marketplace                    5
#            Business to Business Service                    5
#                                 Cottage                    5
#                            Family Hotel                    5
#                     Train Ticket Agency                    5
#                   Price Comparison Site                    5
#                     Cabin Rental Agency                    4
#                       Sport Tour Agency                    4
#                            Holiday Park                    4
#                            Holiday Home                    4
#                             Bus Company                    4
#                    Minibus Taxi Service                    4
#                      Real Estate Agency                    4
#                      Tourist Attraction                    4
#                          License Bureau                    4
#                                  Resort                    4
#                   Valet Parking Service                    4
#                          Business Hotel                    4
#              Tourist Information Center                    4
#                        Boat Tour Agency                    4
#                     Group Accommodation                    3
#                          Parking Garage                    3
#                Passport Photo Processor                    3
#                                    Camp                    3
#                             Hobby Store                    3
#                       Electronics Store                    3
#                       SCUBA Tour Agency                    3
#                                 Airport                    3
#                          Passport Agent                    3
#                     Aviation Consultant                    3
#                  Serviced Accommodation                    3
#                           Airport Hotel                    3
#                         Bed & Breakfast                    3
#             Aviation Training Institute                    2
#                           Camping Store                    2
#               Condominium Rental Agency                    2
#                  Bags and Luggage Store                    2
#                       Insurance Company                    2
#     Telecommunications Service Provider                    2
#          Emergency Veterinarian Service                    2
#                        Insurance Broker                    2
#                            Yacht Broker                    2
#            Furnished Apartment Building                    2
#                                Homestay                    2
#                       Bus Ticket Agency                    2
#                   Pet Insurance Company                    2
#      Recreational Vehicle Rental Agency                    2
#                              Consultant                    2
#      Short Term Apartment Rental Agency                    2
#                                  Hostel                    2
#                        Adventure Sports                    2
#         Recreational and Vacation Camps                    2
#                            Beach Resort                    2
#                        Amusement Center                    2
#                        Activewear Store                    2
#                         Furniture Store                    2
#                             Car Service                    2
#                   International Airport                    2
#                      Hotel Supply Store                    2
#                       Holiday Apartment                    2
#                          Mountain Cabin                    2
#                     Raft Trip Outfitter                    1
#                  Sportwear Manufacturer                    1
#                    Sporting Goods Store                    1
#                       Recreation Center                    1
#                   Search Engine Company                    1
#              Web Collaboration Platform                    1
#                 Mobile Network Operator                    1
#                    Public Parking Space                    1
#                               RV Dealer                    1
#                      e-Commerce Service                    1
#                        Shipping Company                    1
#                               Pet Store                    1
#           Alternative Financial Service                    1
#                           Hunting Store                    1
#                           Wedding Venue                    1
#                            Veterinarian                    1
#                                 Day Spa                    1
#                              Spa Resort                    1
#                  Helicopter Tour Agency                    1
#                      Helicopter Charter                    1
#                   Aircraft Supply Store                    1
#                    Indoor Swimming Pool                    1
#                               Dive Shop                    1
#                        SCUBA Instructor                    1
#                    Outdoor Sports Store                    1
#                            Camera Store                    1
#                                   Class                    1
#          Bar Restaurant Furniture Store                    1
#                     Boat Rental Service                    1
#             Business Networking Company                    1
#                      Apartment Building                    1
#                           Media Company                    1
#                 Restaurant Supply Store                    1
#                  Women's Clothing Store                    1
#                         Underwear Store                    1
#                                  Lounge                    1
#                 Apartment Rental Agency                    1
#                              Log Cabins                    1
#                           Haunted House                    1
#                         Fishing Charter                    1
#                          Lingerie Store                    1
#                   Life Insurance Agency                    1
#              Cell Phone Accessory Store                    1
#                              Photo Shop                    1
#                         Payment Service                    1
#                          History Museum                    1
#                             Review Site                    1
#                  Food Products Supplier                    1
#                Commercial Refrigeration                    1
#                     Baking Supply Store                    1
#                   Animal Rescue Service                    1
#                          Animal Shelter                    1
#            Social Services Organization                    1
#                          Dating Service                    1
#                          Cannabis store                    1
#                    Car Sharing Location                    1
#                       Van Rental Agency                    1
#             Liability Insurance Company                    1
#                           Luggage Store                    1
#                        Regional Airport                    1
#                  Port Operating Company                    1
#                 Health Insurance Agency                    1
#              Outdoor Activity Organiser                    1
#     Driver and Vehicle Licensing Agency                    1
#                              Love Hotel                    1
#                        Website Designer                    1
#                             Social Club                    1
#                         Software Vendor                    1
#                        Cell Phone Store                    1
#                           Event Planner                    1
#                Event Technology Service                    1
#                           Notary Public                    1
#                     Baby Clothing Store                    1
#  Immigration and Naturalization Service                    1
#             Paralegal Services Provider                    1
#                       Foreign Consulate                    1
#               Children's Clothing Store                    1
#     Outdoor Clothing and Equipment Shop                    1
#                          Clothing Store                    1
#                          Legal Services                    1
#                  Real Estate Consultant                    1
#               Credit Counseling Service                    1
#                          Cottage Rental                    1
#                        Wellness Program                    1
#                            Road Cycling                    1
#                         Training School                    1
#               Canoe & Kayak Tour Agency                    1
#                           Flight School                    1
#                   Real Estate Developer                    1
#                     Property Investment                    1
#                                   Lodge                    1
#          Canoe and Kayak Rental Service                    1
#                         Training Centre                    1
#                         Learning Center                    1
#                                Baseball                    1
#                     Recruitment Service                    1
#                           Travel lounge                    1
#           Fitness and Nutrition Service                    1
#               Roommate Referral Service                    1
#                     Event Ticket Seller                    1
#                                 RV Park                    1
#                              Campground                    1
#                           Camping cabin                    1
#                            Soccer Store                    1
#                    Motor Scooter Dealer                    1
#                  Scooter Rental Service                    1
#                Motorcycle Rental Agency                    1
#                      ATV Rental Service                    1
#                  Bicycle Rental Service                    1
#                  House Cleaning Service                    1
#                 Carpet Cleaning Service                    1
#                        Cleaning Service                    1
# Curtain and Upholstery Cleaning Service                    1
#                Balloon Ride Tour Agency                    1
#         Municipal Administration Office                    1
#           Career and Education Provider                    1
# ==================================================
# C:\Users\Dom\AppData\Local\Temp\ipykernel_12056\2080133640.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=top_40_categories.values, y=top_40_categories.index, palette='viridis')
